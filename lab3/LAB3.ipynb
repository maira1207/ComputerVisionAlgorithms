# %% [markdown]
# LAB WORK 3

# %%
import numpy as np
from skimage import data
import matplotlib.pyplot as plt
import random

# %%
image = data.camera()
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        image[i,j] += random.randint(-20,20)

# %%
plt.imshow(image, cmap = plt.cm.gray)

# %%
mm = np.median(image)
print(mm)
# Out:
# 145.0

# %%
binary = image > mm

# %%
plt.imshow(binary, cmap = plt.cm.gray)

# %%
from skimage import feature

edges1 = feature.canny(image,sigma=2,)

# %%
plt.imshow(edges1, cmap = plt.cm.gray)

# %%
edges2 = feature.canny(image,sigma=4.5,low_threshold=5.0,high_threshold=30.0)
plt.imshow(edges2, cmap = plt.cm.gray)
plt.title("RESULT")
# Out:
# Text(0.5, 1.0, 'RESULT')

# %%
image = data.camera()
plt.imshow(image, cmap = plt.cm.gray)

# %%
mm = np.median(image)
binary = image > mm
edges0 = feature.canny(image,sigma=2,)
plt.imshow(edges0, cmap = plt.cm.gray)
plt.title("Original")
# Out:
# Text(0.5, 1.0, 'Original')
